# %%
info = { 112233 : {"company_name"   :  "jio"        ,   "price" :  219 ,  "validity" : 28  ,  "gst_no"  :  1122  ,  "activate_month" : "april" },
         112234 : {"company_name" :    "airtel"     ,   "price" :  399 ,  "validity" : 56  ,  "gst_no"  :  1123  ,  "activate_month" : "june"},
         112235 : {"company_name" :    "VI"         ,   "price" :  598 ,  "validity" : 84  ,  "gst_no"  :  1124  ,  "activate_month" : "may"},
         112236 : {"company_name" :    "vodafone"   ,   "price" :  199 ,  "validity" : 28  ,  "gst_no"  :  1125  ,  "activate_month" : "february"},
         112237 : {"company_name" :    "idea"       ,   "price" :  398 ,  "validity" : 56  ,  "gst_no"  :  1126  ,  "activate_month" : "december"},
         112238 : {"company_name" :    "relaince"   ,   "price" :  498 ,  "validity" : 84  ,  "gst_no"  :  1127  ,  "activate_month" : "august"},
         112239 : {"company_name" :    "gsm"        ,   "price" :  158 ,  "validity" : 28  ,  "gst_no"  :  1128  ,  "activate_month" : "july"},
         112240 : {"company_name" :    "telenor"    ,   "price" :  359 ,  "validity" : 56  ,  "gst_no"  :  1129  ,  "activate_month" : "january"},
         112241 : {"company_name" :    "tata_docomo",   "price" :  599 ,  "validity" : 84  ,  "gst_no"  :  1130  ,  "activate_month" : "march"},
         112242 : {"company_name" :    "uninore"    ,   "price" :  455 ,  "validity" : 28  ,  "gst_no"  :  1131  ,  "activate_month" : "april"},
         112243 : {"company_name" :    "videocon"   ,   "price" :  689 ,  "validity" : 56  ,  "gst_no"  :  1132  ,  "activate_month" : "december"},
         112244 : {"company_name" :    "zing"       ,   "price" :  139 ,  "validity" : 84  ,  "gst_no"  :  1133  ,  "activate_month" : "september"},
         112245 : {"company_name" :    "tata_sky"   ,   "price" :  258 ,  "validity" : 28  ,  "gst_no"  :  1134  ,  "activate_month" : "april"},
         112246 : {"company_name" :    "bsnl"       ,   "price" :  550 ,  "validity" : 56  ,  "gst_no"  :  1135  ,  "activate_month" : "june"},
         112247 : {"company_name" :    "tata_indicom",  "price" :  199,   "validity" : 84  ,  "gst_no"  :  1136  ,  "activate_month" : "may"},
         112248 : {"company_name" :    "aircel"     ,   "price" :  398 ,  "validity" : 28  ,  "gst_no"  :  1137  ,  "activate_month" : "april"},
         112249 : {"company_name" :    "mtnl"       ,   "price" :  589 ,  "validity" : 56  ,  "gst_no"  :  1138  ,  "activate_month" : "august"},
         112250 : {"company_name" :    "bpl"        ,   "price" :  129 ,  "validity" : 84  ,  "gst_no"  :  1139  ,  "activate_month" : "april"},
         112251 : {"company_name" :    "intel"      ,   "price" :  399 ,  "validity" : 28  ,  "gst_no"  :  1140  ,  "activate_month" : "january"},
         112252 : {"company_name" :    "docomo"     ,   "price" :  598 ,  "validity" : 56  ,  "gst_no"  :  1141  ,  "activate_month" : "june"},
         112253 : {"company_name" :    "lg"         ,   "price" :  149 ,  "validity" : 84  ,  "gst_no"  :  1143  ,  "activate_month" : "december"},
         112254 : {"company_name" :    "sab"        ,   "price" :  229 ,  "validity" : 28  ,  "gst_no"  :  1144  ,  "activate_month" : "july"},
         112255 : {"company_name" :    "zing"       ,   "price" :  689 ,  "validity" : 56  ,  "gst_no"  :  1145  ,  "activate_month" : "may"},
         112256 : {"company_name" :    "sony"       ,   "price" :  129 ,  "validity" : 84  ,  "gst_no"  :  1146  ,  "activate_month" : "august"},
         112257 : {"company_name" :    "pal"        ,   "price" :  379 ,  "validity" : 28  ,  "gst_no"  :  1147  ,  "activate_month" : "march"},
         112258:  {"company_name" :    "max"        ,   "price" :  599 , "validity" :  56  ,  "gst_no"  :  1148  ,  "activate_month" : "april"},
         112259 : {"company_name" :    "pogo"       ,   "price" :  199 ,  "validity" : 84  ,  "gst_no"  :  1149  ,  "activate_month" : "september"},
         112260 : {"company_name" :    "sports"     ,   "price" :  399 ,  "validity" : 28  ,  "gst_no"  :  1150  ,  "activate_month" : "november"},
         112261 : {"company_name" :    "live"       ,   "price" :  599 ,  "validity" : 56  ,  "gst_no"  :  1151  ,  "activate_month" : "april"}}

# %%
reg = 112261
print(info[reg]["company_name"])
print(info[reg]["price"])
print(info[reg]["validity"])
print(info[reg]["gst_no"])
print(info[reg]["activate_month"])
# Out:
# live
# 599
# 56
# 1151
# april

# %%
info[reg]["price"] = 199
info[reg]["validity"] = 90


info
# Out:
# {112233: {'company_name': 'jio',
#   'price': 219,
#   'validity': 28,
#   'gst_no': 1122,
#   'activate_month': 'april'},
#  112234: {'company_name': 'airtel',
#   'price': 399,
#   'validity': 56,
#   'gst_no': 1123,
#   'activate_month': 'june'},
#  112235: {'company_name': 'VI',
#   'price': 598,
#   'validity': 84,
#   'gst_no': 1124,
#   'activate_month': 'may'},
#  112236: {'company_name': 'vodafone',
#   'price': 199,
#   'validity': 28,
#   'gst_no': 1125,
#   'activate_month': 'february'},
#  112237: {'company_name': 'idea',
#   'price': 398,
#   'validity': 56,
#   'gst_no': 1126,
#   'activate_month': 'december'},
#  112238: {'company_name': 'relaince',
#   'price': 498,
#   'validity': 84,
#   'gst_no': 1127,
#   'activate_month': 'august'},
#  112239: {'company_name': 'gsm',
#   'price': 158,
#   'validity': 28,
#   'gst_no': 1128,
#   'activate_month': 'july'},
#  112240: {'company_name': 'telenor',
#   'price': 359,
#   'validity': 56,
#   'gst_no': 1129,
# ...

# %%
info = { 112233 : {"company_name"   :  "jio"        ,   "price" :  219 ,  "validity" : 28  ,  "gst_no"  :  1122  ,  "activate_month" : "april" },
         112234 : {"company_name" :    "airtel"     ,   "price" :  399 ,  "validity" : 56  ,  "gst_no"  :  1123  ,  "activate_month" : "june"},
         112235 : {"company_name" :    "VI"         ,   "price" :  598 ,  "validity" : 84  ,  "gst_no"  :  1124  ,  "activate_month" : "may"},
         112236 : {"company_name" :    "vodafone"   ,   "price" :  199 ,  "validity" : 28  ,  "gst_no"  :  1125  ,  "activate_month" : "february"},
         112237 : {"company_name" :    "idea"       ,   "price" :  398 ,  "validity" : 56  ,  "gst_no"  :  1126  ,  "activate_month" : "december"},
         112238 : {"company_name" :    "relaince"   ,   "price" :  498 ,  "validity" : 84  ,  "gst_no"  :  1127  ,  "activate_month" : "august"},
         112239 : {"company_name" :    "gsm"        ,   "price" :  158 ,  "validity" : 28  ,  "gst_no"  :  1128  ,  "activate_month" : "july"},
         112240 : {"company_name" :    "telenor"    ,   "price" :  359 ,  "validity" : 56  ,  "gst_no"  :  1129  ,  "activate_month" : "january"},
         112241 : {"company_name" :    "tata_docomo",   "price" :  599 ,  "validity" : 84  ,  "gst_no"  :  1130  ,  "activate_month" : "march"},
         112242 : {"company_name" :    "uninore"    ,   "price" :  455 ,  "validity" : 28  ,  "gst_no"  :  1131  ,  "activate_month" : "april"},
         112243 : {"company_name" :    "videocon"   ,   "price" :  689 ,  "validity" : 56  ,  "gst_no"  :  1132  ,  "activate_month" : "december"},
         112244 : {"company_name" :    "zing"       ,   "price" :  139 ,  "validity" : 84  ,  "gst_no"  :  1133  ,  "activate_month" : "september"},
         112245 : {"company_name" :    "tata_sky"   ,   "price" :  258 ,  "validity" : 28  ,  "gst_no"  :  1134  ,  "activate_month" : "april"},
         112246 : {"company_name" :    "bsnl"       ,   "price" :  550 ,  "validity" : 56  ,  "gst_no"  :  1135  ,  "activate_month" : "june"},
         112247 : {"company_name" :    "tata_indicom",  "price" :  199,   "validity" : 84  ,  "gst_no"  :  1136  ,  "activate_month" : "may"},
         112248 : {"company_name" :    "aircel"     ,   "price" :  398 ,  "validity" : 28  ,  "gst_no"  :  1137  ,  "activate_month" : "april"},
         112249 : {"company_name" :    "mtnl"       ,   "price" :  589 ,  "validity" : 56  ,  "gst_no"  :  1138  ,  "activate_month" : "august"},
         112250 : {"company_name" :    "bpl"        ,   "price" :  129 ,  "validity" : 84  ,  "gst_no"  :  1139  ,  "activate_month" : "april"},
         112251 : {"company_name" :    "intel"      ,   "price" :  399 ,  "validity" : 28  ,  "gst_no"  :  1140  ,  "activate_month" : "january"},
         112252 : {"company_name" :    "docomo"     ,   "price" :  598 ,  "validity" : 56  ,  "gst_no"  :  1141  ,  "activate_month" : "june"},
         112253 : {"company_name" :    "lg"         ,   "price" :  149 ,  "validity" : 84  ,  "gst_no"  :  1143  ,  "activate_month" : "december"},
         112254 : {"company_name" :    "sab"        ,   "price" :  229 ,  "validity" : 28  ,  "gst_no"  :  1144  ,  "activate_month" : "july"},
         112255 : {"company_name" :    "zing"       ,   "price" :  689 ,  "validity" : 56  ,  "gst_no"  :  1145  ,  "activate_month" : "may"},
         112256 : {"company_name" :    "sony"       ,   "price" :  129 ,  "validity" : 84  ,  "gst_no"  :  1146  ,  "activate_month" : "august"},
         112257 : {"company_name" :    "pal"        ,   "price" :  379 ,  "validity" : 28  ,  "gst_no"  :  1147  ,  "activate_month" : "march"},
         112258:  {"company_name" :    "max"        ,   "price" :  599 , "validity" :  56  ,  "gst_no"  :  1148  ,  "activate_month" : "april"},
         112259 : {"company_name" :    "pogo"       ,   "price" :  199 ,  "validity" : 84  ,  "gst_no"  :  1149  ,  "activate_month" : "september"},
         112260 : {"company_name" :    "sports"     ,   "price" :  399 ,  "validity" : 28  ,  "gst_no"  :  1150  ,  "activate_month" : "november"},
         112261 : {"company_name" :    "live"       ,   "price" :  599 ,  "validity" : 56  ,  "gst_no"  :  1151  ,  "activate_month" : "april"}}

# %%
import json

# %%
js = json.dumps(info)
js
# Out:
# '{"112233": {"company_name": "jio", "price": 219, "validity": 28, "gst_no": 1122, "activate_month": "april"}, "112234": {"company_name": "airtel", "price": 399, "validity": 56, "gst_no": 1123, "activate_month": "june"}, "112235": {"company_name": "VI", "price": 598, "validity": 84, "gst_no": 1124, "activate_month": "may"}, "112236": {"company_name": "vodafone", "price": 199, "validity": 28, "gst_no": 1125, "activate_month": "february"}, "112237": {"company_name": "idea", "price": 398, "validity": 56, "gst_no": 1126, "activate_month": "december"}, "112238": {"company_name": "relaince", "price": 498, "validity": 84, "gst_no": 1127, "activate_month": "august"}, "112239": {"company_name": "gsm", "price": 158, "validity": 28, "gst_no": 1128, "activate_month": "july"}, "112240": {"company_name": "telenor", "price": 359, "validity": 56, "gst_no": 1129, "activate_month": "january"}, "112241": {"company_name": "tata_docomo", "price": 599, "validity": 84, "gst_no": 1130, "activate_month": "mar
# ...

# %%
file = open("file.txt","w")
file.write(js)
file.close()

# %%
file = open("file.txt","r")
a = file.read()
file.close()
a
# Out:
# '{"112233": {"company_name": "jio", "price": 219, "validity": 28, "gst_no": 1122, "activate_month": "april"}, "112234": {"company_name": "airtel", "price": 399, "validity": 56, "gst_no": 1123, "activate_month": "june"}, "112235": {"company_name": "VI", "price": 598, "validity": 84, "gst_no": 1124, "activate_month": "may"}, "112236": {"company_name": "vodafone", "price": 199, "validity": 28, "gst_no": 1125, "activate_month": "february"}, "112237": {"company_name": "idea", "price": 398, "validity": 56, "gst_no": 1126, "activate_month": "december"}, "112238": {"company_name": "relaince", "price": 498, "validity": 84, "gst_no": 1127, "activate_month": "august"}, "112239": {"company_name": "gsm", "price": 158, "validity": 28, "gst_no": 1128, "activate_month": "july"}, "112240": {"company_name": "telenor", "price": 359, "validity": 56, "gst_no": 1129, "activate_month": "january"}, "112241": {"company_name": "tata_docomo", "price": 599, "validity": 84, "gst_no": 1130, "activate_month": "mar
# ...

# %%
info = json.loads(a)
info
# Out:
# {'112233': {'company_name': 'jio',
#   'price': 219,
#   'validity': 28,
#   'gst_no': 1122,
#   'activate_month': 'april'},
#  '112234': {'company_name': 'airtel',
#   'price': 399,
#   'validity': 56,
#   'gst_no': 1123,
#   'activate_month': 'june'},
#  '112235': {'company_name': 'VI',
#   'price': 598,
#   'validity': 84,
#   'gst_no': 1124,
#   'activate_month': 'may'},
#  '112236': {'company_name': 'vodafone',
#   'price': 199,
#   'validity': 28,
#   'gst_no': 1125,
#   'activate_month': 'february'},
#  '112237': {'company_name': 'idea',
#   'price': 398,
#   'validity': 56,
#   'gst_no': 1126,
#   'activate_month': 'december'},
#  '112238': {'company_name': 'relaince',
#   'price': 498,
#   'validity': 84,
#   'gst_no': 1127,
#   'activate_month': 'august'},
#  '112239': {'company_name': 'gsm',
#   'price': 158,
#   'validity': 28,
#   'gst_no': 1128,
#   'activate_month': 'july'},
#  '112240': {'company_name': 'telenor',
#   'price': 359,
#   'validity': 56,
# ...

# %%
info["112250"]
# Out:
# {'company_name': 'bpl',
#  'price': 129,
#  'validity': 84,
#  'gst_no': 1139,
#  'activate_month': 'april'}

# %%
info.items()
# Out:
# dict_items([('112233', {'company_name': 'jio', 'price': 219, 'validity': 28, 'gst_no': 1122, 'activate_month': 'april'}), ('112234', {'company_name': 'airtel', 'price': 399, 'validity': 56, 'gst_no': 1123, 'activate_month': 'june'}), ('112235', {'company_name': 'VI', 'price': 598, 'validity': 84, 'gst_no': 1124, 'activate_month': 'may'}), ('112236', {'company_name': 'vodafone', 'price': 199, 'validity': 28, 'gst_no': 1125, 'activate_month': 'february'}), ('112237', {'company_name': 'idea', 'price': 398, 'validity': 56, 'gst_no': 1126, 'activate_month': 'december'}), ('112238', {'company_name': 'relaince', 'price': 498, 'validity': 84, 'gst_no': 1127, 'activate_month': 'august'}), ('112239', {'company_name': 'gsm', 'price': 158, 'validity': 28, 'gst_no': 1128, 'activate_month': 'july'}), ('112240', {'company_name': 'telenor', 'price': 359, 'validity': 56, 'gst_no': 1129, 'activate_month': 'january'}), ('112241', {'company_name': 'tata_docomo', 'price': 599, 'validity': 84, 'gst_no': 1
# ...
